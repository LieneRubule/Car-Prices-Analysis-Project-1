# %% [markdown]
# # **Data Extraction**

# %% [markdown]
# ## Objectives
#
# * Load the car price dataset and take a first look at the data to understand what information it contains.
#
# ## Inputs
#
# * Car price dataset
# ('CarPrice_Assignment.csv') from the 'Data' folder
#
# ## Outputs
#
# * The car price dataset is saved in the  'Data' folder and ready to use for the next stage and analysis.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\liene\\OneDrive\\Documents\\Car Price Analysis\\Car-Prices-Analysis-Project-1\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\liene\\OneDrive\\Documents\\Car Price Analysis\\Car-Prices-Analysis-Project-1'

# %% [markdown]
# # Load the Dataset

# %% [markdown]
# The dataset is loaded from Data folder, ready to explore and analyse it.

# %%
import pandas as pd

#load the car price dataset
df = pd.read_csv("Data/CarPrice_Assignment.csv")

# %% [markdown]
# ---

# %% [markdown]
# # First Look at the Dataset

# %% [markdown]
# Explore the dataset and its content.

# %%
# Display the first 5 rows of the dataset
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# ### Dataset Size
#
# Check how many rows and collumns are in the dataset.

# %%
# Check the size of the dataset
df.shape
# Out:
# (205, 26)

# %% [markdown]
# ---

# %% [markdown]
# ### Column names
#
# Check the collumn names in the dataset

# %%
# Check the column names in the dataset
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# ### Data types
# Check the data type of each column in the dataset.

# %%
# Check the data types of each column
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # Conclusions and Next steps.

# %% [markdown]
# * The dataset contains 205 rows and 26 columns with a mixture  of  different data.
# * The enext step is to clean the dataset and check for any missing values and duplicates.
